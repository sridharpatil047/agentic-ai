# %%
import csv
import io

# %%
rows = [
    ["Date", "Product", "Units", "Revenue"],
    ["2025-08-01", "Widget A", 10, 250],
    ["2025-08-02", "Widget B", 5, 125],
    ["2025-08-03", "Widget A", 7, 175],
    ["2025-08-04", "Widget C", 3, 90],
]

# %%
buf = io.StringIO()

# %%
buf.getvalue().encode()
# Out:
# b'Date,Product,Units,Revenue\r\n2025-08-01,Widget A,10,250\r\n2025-08-02,Widget B,5,125\r\n2025-08-03,Widget A,7,175\r\n2025-08-04,Widget C,3,90\r\n'

# %%
csv.writer(buf).writerows(rows)
